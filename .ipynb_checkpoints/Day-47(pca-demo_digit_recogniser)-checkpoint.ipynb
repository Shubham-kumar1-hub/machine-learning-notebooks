# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('sample_submission.csv')

# %%
df.head()
# Out:
#    ImageId  Label
# 0        1      0
# 1        2      0
# 2        3      0
# 3        4      0
# 4        5      0

# %%
df.shape
# Out:
# (28000, 2)
