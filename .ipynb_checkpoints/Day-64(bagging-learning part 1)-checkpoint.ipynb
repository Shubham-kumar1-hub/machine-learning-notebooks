# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('IRIS.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
df['species'] = encoder.fit_transform(df['species'])

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
df = df[df['species'] != 0][['sepal_width','petal_length','species']]

# %%
df.head()
# Out:
#     sepal_width  petal_length  species
# 50          3.2           4.7        1
# 51          3.2           4.5        1
# 52          3.1           4.9        1
# 53          2.3           4.0        1
# 54          2.8           4.6        1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.scatter(df['sepal_width'],df['petal_length'],c=df['species'],cmap='winter')

# %%
df = df.sample(100)
df_train = df.iloc[:60,:].sample(10)
df_val = df.iloc[60:80,:].sample(5)
df_test = df.iloc[80:,:].sample(5)

# %%
df_train
# Out:
#      sepal_width  petal_length  species
# 143          3.2           5.9        2
# 79           2.6           3.5        1
# 148          3.4           5.4        2
# 139          3.1           5.4        2
# 113          2.5           5.0        2
# 103          2.9           5.6        2
# 96           2.9           4.2        1
# 89           2.5           4.0        1
# 115          3.2           5.3        2
# 86           3.1           4.7        1

# %%
df_val
# Out:
#      sepal_width  petal_length  species
# 129          3.0           5.8        2
# 56           3.3           4.7        1
# 125          3.2           6.0        2
# 136          3.4           5.6        2
# 141          3.1           5.1        2

# %%
df_test
# Out:
#      sepal_width  petal_length  species
# 112          3.0           5.5        2
# 82           2.7           3.9        1
# 134          2.6           5.6        2
# 137          3.1           5.5        2
# 99           2.8           4.1        1

# %%
X_test = df_val.iloc[:,0:2].values
y_test = df_val.iloc[:,-1].values

# %%
X_test
# Out:
# array([[3. , 5.8],
#        [3.3, 4.7],
#        [3.2, 6. ],
#        [3.4, 5.6],
#        [3.1, 5.1]])

# %%
y_test
# Out:
# array([2, 1, 2, 2, 2])

# %% [markdown]
# # Case 1 - Bagging

# %%
# Data for Tree 1 Replace = TRue means same row can be selected twice.
df_bag = df_train.sample(8,replace=True)

X = df_bag.iloc[:,0:2]
y = df_bag.iloc[:,-1]

df_bag
# Out:
#      sepal_width  petal_length  species
# 86           3.1           4.7        1
# 103          2.9           5.6        2
# 113          2.5           5.0        2
# 148          3.4           5.4        2
# 96           2.9           4.2        1
# 139          3.1           5.4        2
# 143          3.2           5.9        2
# 113          2.5           5.0        2

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from mlxtend.plotting import plot_decision_regions
from sklearn.metrics import accuracy_score

# %%
dt_bag1 = DecisionTreeClassifier()

# %%
def evaluate(clf,X,y):
    clf.fit(X,y)
    plot_tree(clf)
    plt.show()
    plot_decision_regions(X.values,y.values,clf=clf,legend=2)
    y_pred = clf.predict(X_test)
    print(accuracy_score(y_test,y_pred))

# %%
evaluate(dt_bag1,X,y)
# Out:
# C:\Users\skjha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\skjha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 1.0

# %%
# data for tree 2
df_bag = df_train.sample(8,replace=True)

X = df_bag.iloc[:,0:2]
y = df_bag.iloc[:,-1]

df_bag
# Out:
#      sepal_width  petal_length  species
# 103          2.9           5.6        2
# 86           3.1           4.7        1
# 143          3.2           5.9        2
# 148          3.4           5.4        2
# 139          3.1           5.4        2
# 86           3.1           4.7        1
# 115          3.2           5.3        2
# 113          2.5           5.0        2

# %%
dt_bag2 = DecisionTreeClassifier()
evaluate(dt_bag2,X,y)
# Out:
# C:\Users\skjha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\skjha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 1.0

# %%
# data for tree 3
df_bag = df_train.sample(8,replace=True)

X = df_bag.iloc[:,0:2]
y = df_bag.iloc[:,-1]

df_bag
# Out:
#      sepal_width  petal_length  species
# 86           3.1           4.7        1
# 113          2.5           5.0        2
# 86           3.1           4.7        1
# 79           2.6           3.5        1
# 86           3.1           4.7        1
# 79           2.6           3.5        1
# 79           2.6           3.5        1
# 103          2.9           5.6        2

# %%
dt_bag3 = DecisionTreeClassifier()
evaluate(dt_bag3,X,y)
# Out:
# C:\Users\skjha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\skjha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 1.0

# %% [markdown]
# # Predict

# %%
df_test
# Out:
#      sepal_width  petal_length  species
# 112          3.0           5.5        2
# 82           2.7           3.9        1
# 134          2.6           5.6        2
# 137          3.1           5.5        2
# 99           2.8           4.1        1

# %%
print("Predictor 1", dt_bag1.predict(np.array([3.3,5.7]).reshape(1,2)))
print("Predictor 2", dt_bag2.predict(np.array([3.3,5.7]).reshape(1,2)))
print("Predictor 2", dt_bag3.predict(np.array([3.3,5.7]).reshape(1,2)))
# Out:
# Predictor 1 [2]
# Predictor 2 [2]
# Predictor 2 [2]
# C:\Users\skjha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\skjha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\skjha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Pasting

# %%
# Row sampling without replacement
df_train
# Out:
#      sepal_width  petal_length  species
# 143          3.2           5.9        2
# 79           2.6           3.5        1
# 148          3.4           5.4        2
# 139          3.1           5.4        2
# 113          2.5           5.0        2
# 103          2.9           5.6        2
# 96           2.9           4.2        1
# 89           2.5           4.0        1
# 115          3.2           5.3        2
# 86           3.1           4.7        1

# %%
# here we dont do replace.  that is the only difference
df_train.sample(8)
# Out:
#      sepal_width  petal_length  species
# 143          3.2           5.9        2
# 86           3.1           4.7        1
# 115          3.2           5.3        2
# 89           2.5           4.0        1
# 103          2.9           5.6        2
# 79           2.6           3.5        1
# 96           2.9           4.2        1
# 148          3.4           5.4        2

# %% [markdown]
# # Random Subspaces

# %%
# col sampling

# %%
df1 = pd.read_csv('IRIS.csv')

# %%
df1.sample(2,replace=True,axis=1)
# Out:
#      petal_width         species
# 0            0.2     Iris-setosa
# 1            0.2     Iris-setosa
# 2            0.2     Iris-setosa
# 3            0.2     Iris-setosa
# 4            0.2     Iris-setosa
# ..           ...             ...
# 145          2.3  Iris-virginica
# 146          1.9  Iris-virginica
# 147          2.0  Iris-virginica
# 148          2.3  Iris-virginica
# 149          1.8  Iris-virginica
#
# [150 rows x 2 columns]

# %% [markdown]
# # Random Patches

# %%
# both col as well as row sampling

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df1.sample(8,replace=True).sample(2,replace=True,axis=1)
# Out:
#      sepal_length  sepal_width
# 102           7.1          3.0
# 31            5.4          3.4
# 50            7.0          3.2
# 124           6.7          3.3
# 125           7.2          3.2
# 112           6.8          3.0
# 29            4.7          3.2
# 50            7.0          3.2
